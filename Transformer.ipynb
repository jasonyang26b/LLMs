# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd

import lightning as L
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset

# %%
input_vocab = {'<SOS>': 0,
               'lets': 1,
               'to': 2,
               'go': 3}
output_vocab = {'<SOS>': 0,
                'ir': 1,
                'vamos': 2,
                'y': 3,
                '<EOS>': 4}

inputs = torch.tensor([[1,3],  # lets go
                       [2,3]]) # to go

labels = torch.tensor([[2],     # vamos
                       [1]])    # ir

# %% [markdown]
# # Encoder

# %% [markdown]
# # Decoder

# %% [markdown]
# # Encoder - Decoder Attention

# %% [markdown]
# once upon a time
# and every day
# until one day
# and because of this (repeat)
# until finally
# and ever since that day

# %%
# Out:
# 2
